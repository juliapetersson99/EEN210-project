# %%
import pandas as pd
import utils.plotting as pl

data= pd.read_csv('Marten_second.csv')
#data = data[:1000]
windows = pl.split_dataframe_into_sliding_windows(data,"40s")
# Out:
# 2025-01-29 11:39:48.466112
# 2025-01-29 11:40:08.466112
# 2025-01-29 11:40:28.466112
# 2025-01-29 11:40:48.466112

# %%
windows[0]
# Out:
#                       timestamp  acceleration_x  acceleration_y  \
# 0    2025-01-29 11:39:48.466112           -3765            -510
# 1    2025-01-29 11:39:48.466112           -3831            -493
# 2    2025-01-29 11:39:48.468647           -3809            -504
# 3    2025-01-29 11:39:48.468647           -3769            -562
# 4    2025-01-29 11:39:48.484960           -3769            -592
# ...                         ...             ...             ...
# 1139 2025-01-29 11:40:08.375102           -3873            -172
# 1140 2025-01-29 11:40:08.406350           -3862            -189
# 1141 2025-01-29 11:40:08.421972           -3837            -154
# 1142 2025-01-29 11:40:08.437564           -3808            -158
# 1143 2025-01-29 11:40:08.453192           -3834            -142
#
#       acceleration_z  gyroscope_x  gyroscope_y  gyroscope_z     label
# 0                747        -1836         -165          291   walking
# ...

# %%
data_to_display = windows[0]
pl.plot_full_sequence(data_to_display)
